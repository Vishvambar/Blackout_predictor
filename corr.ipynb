# %%
import pandas as pd 
df = pd.DataFrame({
    "study_hours": [1,2,3,4,5],
    "marks" : [35, 40, 50, 65, 75]
})

# %%
print ( df.corr())
# Out:
#              study_hours     marks
# study_hours     1.000000  0.987757
# marks           0.987757  1.000000

# %%
df = pd.DataFrame({
    "Heart_Rate" : [70,80,90,110,130],
    "Risk_Score" : [0.5,0.8,1.2,2.0,3.0]
})

# %%
print(df.corr())
# Out:
#             Heart_Rate  Risk_Score
# Heart_Rate    1.000000    0.997006
# Risk_Score    0.997006    1.000000
